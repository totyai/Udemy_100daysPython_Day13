# %% [markdown]
# # Day 13
# Debugging

# %% [markdown]
# ## Method 1
# Try to describe aloud, what you wanted to achieve and check the code if it does achive it or is there any faily assumption that was made.
# eg. in below the range is NOT including the second value, hence not reaching the **if** statement.

# %%
for i in range(0,20):
    if i == 20:
        print("Hi, there!")

# %% [markdown]
# ## Method 2
# **Reproduce the bug**
# Some bug only appears only some time. In the below example, since the randint can give back 6, but not always, therefore the index 6 could be out of bound.

# %%
from random import randint
dice_images = [1,2,3,4,5,6]
dice_num = 6 #randint(1,6)
print(dice_images[dice_num])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[7], line 4
#       2 dice_images = [1,2,3,4,5,6]
#       3 dice_num = randint(1,6)
# ----> 4 print(dice_images[dice_num])
#
# IndexError: list index out of range

# %% [markdown]
# ## Method 3
# **Act as a computer**
# Think that you are the computer and go line by line over your code. Evaluate each statement and do exactly what the lines would say to do.

# %% [markdown]
# ## Method 4
# **Fix the error**
# Use the IDE's highlighter and if there is an error poping up, fix it right away.
# You can check also the error message coming out in the console and try to search for that error in Google, where it is explained what is there
#
# You can use as well use *try-except* statement. These are wraped around statements that you can not fix, as it depends on other eg. user input. Like below, you can prepare yourself for the error, if the user is not giving a number, but a alphabet

# %%
try:
    age = int(input("How old are you?"))
except:
    print("You have typed in an invalid number. Try again")
    age = int(input("How old are you?"))

if age > 18:
    print("You can drive.")

# %% [markdown]
# ## Method 5
# **Print statement**
# You can use *print* statement. So you can try in the line what it does before going furhter.

# %%
word_per_page = 0
pages = int(input("Number of pages: "))
word_per_page = int(input("Number of words per page: "))
total_words = pages * word_per_page

print(f"pages = {pages}")
print(f"words_per_page = {word_per_page}")
print(total_words)

# %% [markdown]
# ## Method 6
# **Debugger**
# You can create a breakpoint in the left side. This when runs the code, stops there. It is useful to put this before the errourus code. You can review the your variables and go line by line in a slow speed to see every output, even line executed
# Step-over will only goes by my code.
# Step-into will go into the function that some fucntion has been built by others or in other files and we just call it.

# %% [markdown]
# ## Other Tips
# - Some times it is easier if you **take a break**.
# - **Ask a friend** for fresh eyes
# - **Run your code often** - confirm the steps
# - **Ask StackOverflow**

# %% [markdown]
# ## Challanges

# %% [markdown]
# ### Odd or Even
# Read the code in exercise.py - Spot the problems 🐞. - Modify the code to fix the program. Fix the code so that it works and passes the tests when you submit.
#
# ```
# def odd_or_even(number):
#     if number % 2 = 0:
#         return "This is an even number."
#     else:
#         return "This is an odd number."
# ```

# %%
def odd_or_even(number):
    if (number % 2) == 0:
        return "This is an even number."
    else:
        return "This is an odd number."
odd_or_even(5)
# Out:
# 'This is an odd number.'

# %% [markdown]
# ### Leap Year
# - Read the code in exercise.py
#
# - Spot the problems 🐞.
#
# - Modify the code to fix the program.
#
# Fix the code so that it works and when you hit submit it should pass all the tests.
#
# This is how you work out whether if a particular year is a leap year.
# - on every year that is divisible by 4 with no remainder
# - except every year that is evenly divisible by 100 with no remainder
# - unless the year is also divisible by 400 with no remainder
#
# ```
# def is_leap(year):
#     if year % 4 == 0:
#         if year % 100 == 0:
#             if year % 4000 == 0:
#                 return True
#             else:
#                 return False
#         else:
#             return True
#     else:
#         return False
# ```

# %%
def is_leap(year):
    if year % 4 == 0:
        if year % 100 == 0:
            if year % 400 == 0:
                return True
            else:
                return False
        else:
            return True
    else:
        return False

# %% [markdown]
# ### FizzBuzz
# - Read the code in exercise.py
# - Spot the problems 🐞.
# - Modify the code to fix the program.
# - No shortcuts
# - don't copy-paste to replace the code entirely with a previous working solution.
#
# The code needs to print the solution to the FizzBuzz game.
# - Your program should print each number from 1 to x where x is the input number.
# - However when the number is divisible by 3 then instead of printing the number it should print "Fizz".
# - When the number is divisible by 5, then instead of printing the number it should print "Buzz".
# - And if the number is divisible by both 3 and 5 e.g. 15 then instead of the number it should print "FizzBuzz".
#
# ```
# Target is the number up to which we count
# def fizz_buzz(target):
#     for number in range(1, target + 1):
#         if number % 3 == 0 or number % 5 == 0:
#             print("FizzBuzz")
#         if number % 3 == 0:
#             print("Fizz")
#         if number % 5 == 0:
#             print("Buzz")
#         else:
#             print([number])
#
# ```

# %%
# Target is the number up to which we count
def fizz_buzz(target):
    for number in range(1, target + 1):
        if ((number % 3) == 0) and ((number % 5) == 0):
            print("FizzBuzz")
        elif number % 3 == 0:
            print("Fizz")
        elif number % 5 == 0:
            print("Buzz")
        else:
            print(number)

fizz_buzz(35)
# Out:
# 1
# 2
# Fizz
# 4
# Buzz
# Fizz
# 7
# 8
# Fizz
# Buzz
# 11
# Fizz
# 13
# 14
# FizzBuzz
# 16
# 17
# Fizz
# 19
# Buzz
# Fizz
# 22
# 23
# Fizz
# Buzz
# 26
# Fizz
# 28
# 29
# FizzBuzz
# 31
# 32
# Fizz
# 34
# Buzz
